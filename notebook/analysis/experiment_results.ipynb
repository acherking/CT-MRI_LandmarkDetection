# %% [markdown]
# ## results table

# %%
# Down-Net-fc
# /data/gpfs/projects/punim1836/CT-MRI_LandmarkDetection/models/cropped/63x50x61/noises_s1_test_dis/two_landmarks/straight_model/learning_rate/0.0001/16Jul2024-17:05:07-trainID-33
# Train: {'mean_dis_all': 0.109, 'epoch': 91, 'time(h)': 0.13}
# Train:  {'mean_dis_all': 0.071, 'std_dev_all': 0.04, 'mean_dis_1': 0.071, 'std_dev_1': 0.042, 'mean_dis_2': 0.071, 'std_dev_2': 0.038}
# Val :  {'mean_dis_all': 0.172, 'std_dev_all': 0.087, 'mean_dis_1': 0.171, 'std_dev_1': 0.101, 'mean_dis_2': 0.173, 'std_dev_2': 0.07}
# Test:  {'mean_dis_all': 0.246, 'std_dev_all': 0.128, 'mean_dis_1': 0.2, 'std_dev_1': 0.121, 'mean_dis_2': 0.292, 'std_dev_2': 0.117}

# Down-Net-dsnt
# /data/gpfs/projects/punim1836/CT-MRI_LandmarkDetection/models/cropped/63x50x61/noises_s1_test_dis/two_landmarks/down_net_dsnt/learning_rate/0.00005/16Jul2024-17:21:30-trainID-3
# Train: {'mean_dis_all': 0.297, 'epoch': 85, 'time(h)': 0.12}
# Train:  {'mean_dis_all': 0.293, 'std_dev_all': 0.457, 'mean_dis_1': 0.332, 'std_dev_1': 0.4, 'mean_dis_2': 0.253, 'std_dev_2': 0.505}
# Val :  {'mean_dis_all': 0.346, 'std_dev_all': 0.385, 'mean_dis_1': 0.363, 'std_dev_1': 0.334, 'mean_dis_2': 0.328, 'std_dev_2': 0.429}
# Test:  {'mean_dis_all': 0.387, 'std_dev_all': 0.418, 'mean_dis_1': 0.314, 'std_dev_1': 0.323, 'mean_dis_2': 0.46, 'std_dev_2': 0.485}

# Down-Net-Short-fc
# /data/gpfs/projects/punim1836/CT-MRI_LandmarkDetection/models/cropped/63x50x61/noises_s1_test_dis/two_landmarks/down_net_short/learning_rate/0.0005/16Jul2024-17:36:21-trainID-2.1
# Train: {'mean_dis_all': 0.265, 'epoch': 85, 'time(h)': 0.08}
# Train:  {'mean_dis_all': 0.143, 'std_dev_all': 0.076, 'mean_dis_1': 0.16, 'std_dev_1': 0.07, 'mean_dis_2': 0.126, 'std_dev_2': 0.077}
# Val :  {'mean_dis_all': 0.286, 'std_dev_all': 0.158, 'mean_dis_1': 0.256, 'std_dev_1': 0.167, 'mean_dis_2': 0.317, 'std_dev_2': 0.143}
# Test:  {'mean_dis_all': 0.381, 'std_dev_all': 0.249, 'mean_dis_1': 0.295, 'std_dev_1': 0.202, 'mean_dis_2': 0.467, 'std_dev_2': 0.262}

# Down-Net-Short-dsnt
# /data/gpfs/projects/punim1836/CT-MRI_LandmarkDetection/models/cropped/63x50x61/noises_s1_test_dis/two_landmarks/down_net_short_dsnt/learning_rate/0.0001/16Jul2024-17:47:28-trainID-2
# Train: {'mean_dis_all': 0.313, 'epoch': 75, 'time(h)': 0.07}
# Train:  {'mean_dis_all': 0.319, 'std_dev_all': 0.446, 'mean_dis_1': 0.352, 'std_dev_1': 0.388, 'mean_dis_2': 0.285, 'std_dev_2': 0.495}
# Val :  {'mean_dis_all': 0.414, 'std_dev_all': 0.383, 'mean_dis_1': 0.407, 'std_dev_1': 0.331, 'mean_dis_2': 0.42, 'std_dev_2': 0.428}
# Test:  {'mean_dis_all': 0.481, 'std_dev_all': 0.408, 'mean_dis_1': 0.376, 'std_dev_1': 0.322, 'mean_dis_2': 0.586, 'std_dev_2': 0.455}

# U-Net-fc
# /data/gpfs/projects/punim1836/CT-MRI_LandmarkDetection/models/cropped/63x50x61/noises_s1_test_dis/two_landmarks/u_net/learning_rate/0.0001/16Jul2024-17:59:06-trainID-2
# Train: {'mean_dis_all': 0.123, 'epoch': 82, 'time(h)': 0.89}
# Train:  {'mean_dis_all': 0.097, 'std_dev_all': 0.043, 'mean_dis_1': 0.1, 'std_dev_1': 0.043, 'mean_dis_2': 0.094, 'std_dev_2': 0.042}
# Val :  {'mean_dis_all': 0.267, 'std_dev_all': 0.155, 'mean_dis_1': 0.242, 'std_dev_1': 0.157, 'mean_dis_2': 0.293, 'std_dev_2': 0.149}
# Test:  {'mean_dis_all': 0.419, 'std_dev_all': 0.253, 'mean_dis_1': 0.248, 'std_dev_1': 0.142, 'mean_dis_2': 0.59, 'std_dev_2': 0.223}
# 
# U-Net-dsnt
# /data/gpfs/projects/punim1836/CT-MRI_LandmarkDetection/models/cropped/63x50x61/noises_s1_test_dis/two_landmarks/u_net_dsnt/learning_rate/0.0001/16Jul2024-19:45:20-trainID-13
# Train: {'mean_dis_all': 0.054, 'epoch': 81, 'time(h)': 0.89}
# Train:  {'mean_dis_all': 0.059, 'std_dev_all': 0.031, 'mean_dis_1': 0.043, 'std_dev_1': 0.019, 'mean_dis_2': 0.074, 'std_dev_2': 0.033}
# Val :  {'mean_dis_all': 0.183, 'std_dev_all': 0.1, 'mean_dis_1': 0.129, 'std_dev_1': 0.066, 'mean_dis_2': 0.238, 'std_dev_2': 0.098}
# Test:  {'mean_dis_all': 0.29, 'std_dev_all': 0.206, 'mean_dis_1': 0.154, 'std_dev_1': 0.097, 'mean_dis_2': 0.425, 'std_dev_2': 0.197}
# 
# SCN-fc
# /data/gpfs/projects/punim1836/CT-MRI_LandmarkDetection/models/cropped/63x50x61/noises_s1_test_dis/two_landmarks/scn/learning_rate/0.0001/16Jul2024-17:21:59-trainID-2
# Train: {'mean_dis_all': 0.201, 'epoch': 98, 'time(h)': 2.07}
# Train:  {'mean_dis_all': 0.206, 'std_dev_all': 0.076, 'mean_dis_1': 0.196, 'std_dev_1': 0.073, 'mean_dis_2': 0.217, 'std_dev_2': 0.078}
# Val :  {'mean_dis_all': 0.562, 'std_dev_all': 0.256, 'mean_dis_1': 0.512, 'std_dev_1': 0.262, 'mean_dis_2': 0.611, 'std_dev_2': 0.24}
# Test:  {'mean_dis_all': 0.76, 'std_dev_all': 0.425, 'mean_dis_1': 0.593, 'std_dev_1': 0.332, 'mean_dis_2': 0.928, 'std_dev_2': 0.442}
# 
# SCN-dsnt
# /data/gpfs/projects/punim1836/CT-MRI_LandmarkDetection/models/cropped/63x50x61/noises_s1_test_dis/two_landmarks/scn_dsnt/learning_rate/0.0001/16Jul2024-20:47:59-trainID-11
# Train: {'mean_dis_all': 0.105, 'epoch': 95, 'time(h)': 2.04}
# Train:  {'mean_dis_all': 0.084, 'std_dev_all': 0.045, 'mean_dis_1': 0.08, 'std_dev_1': 0.042, 'mean_dis_2': 0.089, 'std_dev_2': 0.048}
# Val :  {'mean_dis_all': 0.434, 'std_dev_all': 0.213, 'mean_dis_1': 0.384, 'std_dev_1': 0.224, 'mean_dis_2': 0.485, 'std_dev_2': 0.188}
# Test:  {'mean_dis_all': 0.47, 'std_dev_all': 0.233, 'mean_dis_1': 0.341, 'std_dev_1': 0.198, 'mean_dis_2': 0.598, 'std_dev_2': 0.191}
